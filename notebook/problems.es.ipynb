# %% [markdown]
# # Problemas de distribución de probabilidad

# %% [markdown]
# ## Distribución binomial
#
# En teoría de la probabilidad y estadística, la distribución binomial es la distribución de probabilidad discreta que da sólo dos resultados posibles en un experimento; por ejemplo, al lanzar una moneda, puede salir cara o cruz.

# %%
from scipy.stats import binom

# Definir todas las funciones de probabilidad relacionadas con esta distribución.

def dbinom(x, size, prob = 0.5):
    """
    Calcula la estimación puntual de la distribución binomial.
    """
    result = binom.pmf(k = x, n = size, p = prob, loc = 0)

    return result

def pbinom(q, size, prob = 0.5):
    """
    Calcula el acumulado de la distribución binomial.
    """
    result = binom.cdf(k = q, n = size, p = prob, loc = 0)

    return result

def qbinom(p, size, prob = 0.5):
    """
    Calcula la función cuantil a partir de la distribución binomial.
    """
    result = binom.ppf(q = p, n = size, p = prob, loc = 0)

    return result

def rbinom(n, size, prob = 0.5):
    """
    Genera variables aleatorias a partir de la distribución binomial.
    """
    result = binom.rvs(n = size, p = prob, size = n)

    return result

# %%
# Distribución binomial(10, 0.2), dónde n = 10 es el número de ensayos y p = 0.2 es la probabilidad de éxito en un solo ensayo
import numpy as np

np.random.seed(42)

print(f"Probability that a Binomial(10, 0.2) takes the value 2: {dbinom(2, size = 10, prob = 0.2)}")
print(f"Probability that a Binomial(10, 0.2) will take a value less than 2: {pbinom(2, size = 10, prob = 0.2)}")
print(f"Which value of a Binomial(10, 0.2) has a cumulative probability of 0.9? {qbinom(0.9, size = 10, prob = 0.2)}")
print(f"Generate 2000 random values from a Binomial(10, 0.2) distribution: {rbinom(2000, size = 10, prob = 0.2)}")
# Out:
# Probability that a Binomial(10, 0.2) takes the value 2: 0.30198988800000004
# Probability that a Binomial(10, 0.2) will take a value less than 2: 0.6777995263999999
# Which value of a Binomial(10, 0.2) has a cumulative probability of 0.9? 4.0
# Generate 2000 random values from a Binomial(10, 0.2) distribution: [1 4 3 ... 0 0 1]

# %%
import matplotlib.pyplot as plt

np.random.seed(42)

size = 10
prob = 0.2
data = rbinom(2000, size = 10, prob = 0.2)

pmf = dbinom(data, size = size, prob = prob)
cdf = pbinom(data, size = size, prob = prob)
ppf = qbinom(data, size = size, prob = prob)

fig, axis = plt.subplots(3, 1, figsize = (5, 7))

axis[0].stem(data, pmf, "r-")
axis[1].stem(data, cdf, "b-")
axis[2].stem(data, ppf, "g-")

# Adjust the layout
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ## Ejercicio 1
#
# Escriba las funciones anteriores pero para distribuciones normales y uniformes.

# %%
# TODO

#Librerias importadas

import numpy as np 
import matplotlib.pyplot as plt
from scipy.stats import norm
np.random.seed(42)

#Distribución normal 

media = 0
dt= 1
N= 100

datos= np.arange(-7, 7, 0.02)


print(f"La media de los datos es: {stats.mean(datos)}")
print(f"La desviación estándar de los datos es: {stats.stdev(datos)}")

def dnorm (x,mean,std):
    result= norm.pdf(x, loc=mean, scale=std)
    return result 

def cnorm (x,mean,std):
    result= norm.cdf(x, loc=mean, scale=std)
    return result 

def qnorm (p,mean,std):
    result= norm.ppf(q=p, loc=mean, scale=std)
    return result 

#Gráficos 

fig, axis = plt.subplots(nrows=1,ncols=3, figsize=(13,2))

pdf= dnorm(datos,media,dt)
cdf= cnorm(datos,media,dt)
ppf= qnorm(datos,media,dt)

axis[0].plot(datos,pdf,"y")
axis[1].plot(datos,cdf,"m")
axis[2].plot(datos,ppf,"c")
axis[0].set_title("Distribución normal (PDF)")
axis[1].set_title("Distribución normal (CDF)")
axis[2].set_title("Distribución normal (PPF)")


#Distribución uniforme

from scipy.stats import uniform


def duniform (x,mean,std):
    result= uniform.pdf(x, loc=mean, scale=std)
    return result 

def cuniform (x,mean,std):
    result= uniform.cdf(x, loc=mean, scale=std)
    return result 

def quniform (p,mean,std):
    result= uniform.ppf(q=p, loc=mean, scale=std)
    return result 

#Gráficos 

fig, axis = plt.subplots(nrows=3,ncols=1,)

pdfu= duniform(datos,media,dt)
cdfu= cuniform(datos,media,dt)
ppfu= quniform(datos,media,dt)

axis[0].plot(datos,pdfu,"k")
axis[1].plot(datos,cdfu,"r")
axis[2].plot(datos,ppfu,"g")
axis[0].set_title("Distribución uniforme (PDF)", fontsize=10)
axis[1].set_title("Distribución uniforme (CDF)", fontsize=10)
axis[2].set_title("Distribución uniforme (PPF)", fontsize=10)

#¿Cómo puedo separar más los gráficos para poder ponerlos en 3 filas y 1 columna sin que se sobrepongan los títulos?
# Out:
# La media de los datos es: -0.010000000000149
# La desviación estándar de los datos es: 4.044337605426378
# Text(0.5, 1.0, 'Distribución uniforme (PPF)')
